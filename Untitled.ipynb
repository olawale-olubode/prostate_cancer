# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import classification_report
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
raw_data = pd.read_csv("raw_data.csv")
raw_data.sample(5)
# Out:
#        URBRRL  RATCAT_A  IMPINCFLG_A  CVDVAC2YR_A  CVDVAC2MR_A  CVDVAC1YR_A  \
# 26574       3        14            0       2021.0          2.0       2021.0
# 17875       3        11            0       2021.0          2.0       2021.0
# 9642        2        12            0          NaN          NaN          NaN
# 21932       3         8            1       2021.0          1.0       2021.0
# 27903       1        14            0       2021.0          8.0       2021.0
#
#        CVDVAC1MR_A  SHTCVD19AV_A  SHTCVD19NM_A  SHTCVD19_A  ASPONOWN_A  \
# 26574          3.0           NaN           2.0         1.0         2.0
# 17875          3.0           NaN           2.0         1.0         2.0
# 9642           NaN           NaN           NaN         2.0         2.0
# 21932          3.0           NaN           2.0         1.0         NaN
# 27903          9.0           NaN           2.0         1.0         2.0
#
#        ASPMEDSTP_A  ASPMEDNOWN_A  ASPMEDEV_A  LSROTATE_FLG  PPSU  PSTRAT  \
# 26574          NaN           NaN         2.0           1.0    74     147
# 17875          NaN           NaN         2.0           1.0    12     127
# 9642           NaN           NaN         2.0           1.0    51     139
# 21932          NaN           1.0         1.0           2.0     1     103
# 27903          NaN           NaN         2.0           2.0     3     133
#
#        HISPALLP_A  RACEALLP_A  DISAB3_A  K6SPD_A  SCHDYMSSTC_A  AFNOW  \
# 26574           2           1         2        2           NaN    2.0
# 17875           2           1         2        2           NaN    NaN
# 9642            4           3         2        2           NaN    2.0
# 21932           2           1         2        2           NaN    NaN
# 27903           2           1         2        2           NaN    2.0
#
#        REPWRKDYTC_A  YRSINUS_A  CITZNSTP_A  PRTNREDUCP_A  SPOUSEDUCP_A  \
# 26574           NaN        NaN           1           NaN           4.0
# 17875           NaN        NaN           1           NaN           8.0
# 9642            NaN        5.0           2           NaN           NaN
# 21932           NaN        NaN           1           NaN           NaN
# 27903           NaN        NaN           1           NaN           5.0
#
#        LEGMSTAT_A  MARSTAT_A  SASPPRACE_A  SASPPHISP_A  PRTNRAGETC_A  \
# 26574           3          1          1.0          1.0           NaN
# 17875           3          1          1.0          1.0           NaN
# 9642            4          7          NaN          NaN           NaN
# 21932           5          4          NaN          NaN           NaN
# 27903           3          1          1.0          1.0           NaN
#
#        SPOUSAGETC_A  PRTNRWKFT_A  PRTNRWRK_A  SPOUSWKFT_A  SPOUSWRK_A  \
# 26574          62.0          NaN         NaN          1.0         1.0
# 17875          85.0          NaN         NaN          NaN         2.0
# 9642            NaN          NaN         NaN          NaN         NaN
# 21932           NaN          NaN         NaN          NaN         NaN
# 27903          44.0          NaN         NaN          1.0         1.0
#
#        SPOUSESEX_A  PRTNRSEX_A  INJWRKDYTC_A  NUMINJTC_A  SHINGRXYRP_A  \
# 26574          1.0         NaN           NaN         NaN        2019.0
# 17875          2.0         NaN           NaN         NaN           NaN
# 9642           NaN         NaN           NaN         NaN           NaN
# 21932          NaN         NaN           NaN         NaN           NaN
# 27903          1.0         NaN           NaN         NaN           NaN
#
#        ZOSTAVXYRP_A  HHRESPSA_FLG  PCNTADTWFP_A  PCNTADTWKP_A  FDSCAT4_A  \
# 26574           NaN           NaN             1             1          1
# 17875        2018.0           1.0             0             0          1
# 9642            NaN           1.0             1             1          1
# 21932           NaN           1.0             0             0          1
# 27903           NaN           1.0             2             2          1
#
#        FDSCAT3_A  EPINUMSEZP_A  EMPDYSMSS3_A  EMPLSTWOR1_A  EMPWRKFT1_A  \
# 26574          1           NaN           0.0           1.0          NaN
# 17875          1           NaN           NaN           3.0          NaN
# 9642           1           NaN           0.0           NaN          1.0
# 21932          1           NaN           NaN           3.0          NaN
# 27903          1           NaN           2.0           NaN          1.0
#
#        EMPWRKLSW1_A  EMPWKHRS3_A  EMDOCCUPN2_A  EMDOCCUPN1_A  EMDINDSTN2_A  \
# 26574             2          NaN           2.0           6.0          15.0
# 17875             2          NaN           NaN           NaN           NaN
# 9642              1         40.0          21.0          86.0           5.0
# 21932             2          NaN           NaN           NaN           NaN
# 27903             1         40.0           8.0          21.0          15.0
#
#        EMDINDSTN1_A  DIBAGETC_A  DIFYRSTC1_A  SMKECIGST_A  SMKCIGST_A  \
# 26574          64.0         NaN          NaN            3           4
# 17875           NaN         NaN          NaN            3           4
# 9642           31.0         NaN          NaN            3           4
# 21932           NaN         NaN          NaN            3           4
# 27903          64.0         NaN          NaN            3           4
#
#        BMICAT_A  WEIGHTLBTC_A  HEIGHTTC_A  URGNT12MTC_A  EMERG12MTC_A  \
# 26574         2           118          64             0             0
# 17875         2           139          63             2             0
# 9642          2           996          96             0             0
# 21932         3           168          67             0             0
# 27903         3           996          96             0             0
#
#        CLSWRKNOS1_A  CLSWRKSD1_A  JOBANYSD1_A  DIBA1CNMT_A  PCNT18UPTC  \
# 26574           1.0          1.0          1.0          NaN           2
# 17875           NaN          NaN          NaN          NaN           2
# 9642            3.0          3.0          1.0          NaN           1
# 21932           NaN          NaN          NaN          NaN           1
# 27903           1.0          2.0          1.0          NaN           2
#
#        PCNTLT18TC  LSATIS4R_A  LSATIS11R_A  COVER65_A  COVER_A  EXCHANGE_A  \
# 26574           0           1           10        NaN      1.0         2.0
# 17875           0           1            9        2.0      NaN         NaN
# 9642            0           1            7        NaN      1.0         2.0
# 21932           0           2            7        5.0      NaN         NaN
# 27903           2           2            7        NaN      1.0         2.0
#
#        NOTCOV_A  MILSPC1R_A  OGFLG_A  OPFLG_A  CHFLG_A  MAFLG_A  PLNWRKR2_A  \
# 26574         2         NaN      NaN      NaN      NaN      NaN         NaN
# 17875         2         NaN      NaN      NaN      NaN      NaN         NaN
# 9642          2         NaN      NaN      NaN      NaN      NaN         NaN
# 21932         2         1.0      NaN      NaN      NaN      NaN         NaN
# 27903         2         NaN      NaN      NaN      NaN      NaN         NaN
#
#        PLNWRKR1_A  RSNHIMISS_A  RSNHIJOB_A  MCADVR_A  PRFLG_A  PLEXCHPR1_A  \
# 26574         1.0          NaN         NaN       NaN      NaN          NaN
# 17875         NaN          NaN         NaN       NaN      NaN          NaN
# 9642          2.0          NaN         NaN       NaN      NaN          NaN
# 21932         NaN          NaN         NaN       NaN      NaN          NaN
# 27903         1.0          NaN         NaN       NaN      NaN          NaN
#
#        PRPREM1_A  PXCHNG1_A  HICOSTR2_A  HICOSTR1_A  OTHGOV_A  OTHPUB_A  \
# 26574        NaN        NaN         NaN      8868.0         3         3
# 17875        NaN        NaN         NaN         NaN         3         3
# 9642         NaN        NaN         NaN      4200.0         3         3
# 21932        NaN        NaN         NaN         NaN         3         3
# 27903        NaN        NaN         NaN     99999.0         3         3
#
#        IHS_A  MILITARY_A  CHIP_A  MEDICAID_A  MEDICARE_A  PRIVATE_A  \
# 26574      2           3       3           3           3          1
# 17875      2           3       3           1           1          3
# 9642       2           3       3           3           3          1
# 21932      2           1       3           3           1          3
# 27903      2           3       3           3           3          1
#
#        PRPLCOV1_C_A  PRPLCOV2_C_A  PLEXCHOG_A  PLEXCHOP_A  EXCHPR2_A  \
# 26574           NaN           NaN         NaN         NaN        NaN
# 17875           NaN           NaN         NaN         NaN        NaN
# 9642            NaN           NaN         NaN         NaN        NaN
# 21932           NaN           NaN         NaN         NaN        NaN
# 27903           NaN           NaN         NaN         NaN        NaN
#
#        EXCHPR1_A  EDUCP_A  MAXEDUCP_A  PARSTAT_A  SAPARENTSC_A  MLTFAMFLG_A  \
# 26574        2.0        9         9.0          3             3            2
# 17875        NaN       10        10.0          3             3            2
# 9642         2.0        4         4.0          3             3            2
# 21932        NaN        8         8.0          3             3            2
# 27903        1.0        9         9.0          1             1            2
#
#        OVER65FLG_A  PCNTADLT_A  PCNTKIDS_A  NUMCAN_A  COLRCAGETC_A  \
# 26574            0           2           0         0           NaN
# 17875            1           2           0         2           NaN
# 9642             0           1           0         0           NaN
# 21932            1           1           0         0           NaN
# 27903            0           2           2         0           NaN
#
#        HDNCKAGETC_A  OTHERAGETC_A  UTERUAGETC_A  THYROAGETC_A  THROAAGETC_A  \
# 26574           NaN           NaN           NaN           NaN           NaN
# 17875           NaN          85.0           NaN           NaN           NaN
# 9642            NaN           NaN           NaN           NaN           NaN
# 21932           NaN           NaN           NaN           NaN           NaN
# 27903           NaN           NaN           NaN           NaN           NaN
#
#        STOMAAGETC_A  SKNDKAGETC_A  SKNNMAGETC_A  SKNMAGETC_A  RECTUAGETC_A  \
# 26574           NaN           NaN           NaN          NaN           NaN
# 17875           NaN           NaN          45.0          NaN           NaN
# 9642            NaN           NaN           NaN          NaN           NaN
# 21932           NaN           NaN           NaN          NaN           NaN
# 27903           NaN           NaN           NaN          NaN           NaN
#
#        PROSTAGETC_A  PANCRAGETC_A  OVARYAGETC_A  MOUTHAGETC_A  MELANAGETC_A  \
# 26574           NaN           NaN           NaN           NaN           NaN
# 17875           NaN           NaN           NaN           NaN           NaN
# 9642            NaN           NaN           NaN           NaN           NaN
# 21932           NaN           NaN           NaN           NaN           NaN
# 27903           NaN           NaN           NaN           NaN           NaN
#
# 21932         NaN         NaN        NaN         NaN         NaN          3
# 27903         NaN         NaN        NaN         NaN         NaN          3
#
#        HISP_A  REGION  INTV_QRT  SRVY_YR  SEX_A  AGEP_A  AGE65  ASTATNEW  \
# 26574       2       2         4     2021      2      59    NaN         1
# 17875       2       2         3     2021      1      85    NaN         1
# 9642        2       3         2     2021      1      46    NaN         1
# 21932       2       3         4     2021      2      66    NaN         1
# 27903       2       2         4     2021      2      41    NaN         1
#
#        HOUGVASST_A  HOUTENURE_A  HOUYRSLIV_A  FDSNEDAYS_A  FDSNOTEAT_A  \
# 26574          NaN            1            5          NaN          NaN
# 17875          NaN            1            3          NaN          NaN
# 9642           NaN            1            4          NaN          NaN
# 21932          NaN            1            3          NaN          NaN
# 27903          NaN            1            3          NaN          NaN
#
#        FDSWEIGHT_A  FDSHUNGRY_A  FDSLESS_A  FDSSKIPDYS_A  FDSSKIP_A  \
# 26574          NaN          NaN        NaN           NaN        NaN
# 17875          NaN          NaN        NaN           NaN        NaN
# 9642           NaN          NaN        NaN           NaN        NaN
# 21932          NaN          NaN        NaN           NaN        NaN
# 27903          NaN          NaN        NaN           NaN        NaN
#
#        FDSBALANCE_A  FDSLAST_A  FDSRUNOUT_A  FLUNCH12M_A  FWIC12M_A  \
# 26574             3          3            3          NaN        NaN
# 17875             3          3            3          NaN        NaN
# 9642              3          3            3          NaN        NaN
# 21932             3          3            3          NaN        NaN
# 27903             3          3            3          1.0        2.0
#
#        FSNAP30D_A  FSNAP12M_A  INCOTHR_A  INCRETIRE_A  INCWELF_A  \
# 26574         NaN           2        2.0          1.0        2.0
# 17875         NaN           2        2.0          1.0        2.0
# 9642          NaN           2        2.0          2.0        2.0
# 21932         NaN           2        1.0          1.0        2.0
# 27903         NaN           2        2.0          2.0        2.0
#
#        SSISSDIDSB_A  SSISSDIBTH_A  INCSSISSDI_A  INCSSRR_A  INCINTER_A  \
# 26574           NaN           NaN           2.0        2.0           1
# 17875           NaN           NaN           2.0        1.0           1
# 9642            NaN           NaN           2.0        2.0           2
# 21932           NaN           NaN           2.0        1.0           2
# 27903           NaN           NaN           2.0        2.0           1
#
#        INCWRKO_A  RJCLSOFT1_A  RJCLSNOSD1_A  RJCLSSD1_A  RECJOBSD1_A  \
# 26574          1          NaN           1.0         1.0          1.0
# 17875          2          NaN           NaN         NaN          NaN
# 9642           1          NaN           NaN         NaN          NaN
# 21932          2          NaN           NaN         NaN          NaN
# 27903          1          NaN           NaN         NaN          NaN
#
#        SDMSRSOFT1_A  SDMSRS1_A  WRKCLSOFT1_A  WRKCLSNSD1_A  WRKCLSSD1_A  \
# 26574           NaN        NaN           NaN           NaN          NaN
# 17875           NaN        NaN           NaN           NaN          NaN
# 9642            NaN        NaN           NaN           3.0          3.0
# 21932           NaN        NaN           NaN           NaN          NaN
# 27903           NaN        NaN           NaN           1.0          2.0
#
#        CURJOBSD1_A  JOBMISS_A  JOBWRKSICK_A  JOBLKYLOSS_A  JOBADVSCH_A  \
# 26574          NaN        NaN           NaN           NaN          6.0
# 17875          NaN        NaN           NaN           NaN          NaN
# 9642           1.0        0.0           0.0           4.0          NaN
# 21932          NaN        NaN           NaN           NaN          NaN
# 27903          1.0        0.0           0.0           4.0          NaN
#
#        JOBVARYSCH_A  JOBCHGSCH_A  JOBSHIFT_A  JOBCHGEARN_A  JOBTAX_A  \
# 26574           1.0          1.0         1.0           2.0       1.0
# 17875           NaN          NaN         NaN           NaN       NaN
# 9642            2.0          1.0         1.0           1.0       1.0
# 21932           NaN          NaN         NaN           NaN       NaN
# 27903           2.0          3.0         1.0           1.0       1.0
#
#        EMDWRKCAT1_A  EMDSUPER_A  EMPHEALINS_A  EMPSICKLV_A  EMPWHYNOT_A  \
# 26574           4.0         1.0           2.0          2.0          3.0
# 17875           NaN         NaN           NaN          NaN          3.0
# 9642            1.0         2.0           1.0          1.0          NaN
# 21932           NaN         NaN           NaN          NaN          3.0
# 27903           1.0         1.0           1.0          1.0          NaN
#
#        SCHCURENR_A  NATUSBORN_A  VACAREEV_A  VAHOSP_A  VADISB_A  COMBAT_A  \
# 26574            2            1         NaN       NaN       NaN       NaN
# 17875            2            1         2.0       2.0       2.0       1.0
# 9642             2            2         NaN       NaN       NaN       NaN
# 21932            2            1         NaN       1.0       1.0       1.0
# 27903            2            1         NaN       NaN       NaN       NaN
#
#        AFVETTRN_A  AFVET_A  EVRMARRIED_A  SPOUSEP_A  SPOUSLIV_A  MARITAL_A  \
# 26574         NaN        2           NaN        NaN         1.0          1
# 17875         2.0        1           NaN        NaN         1.0          1
# 9642          NaN        2           2.0        NaN         NaN          3
# 21932         2.0        1           1.0        NaN         NaN          3
# 27903         NaN        2           NaN        NaN         1.0          1
#
#        ORIENT_A  CMPSUPPORT_A  SUPPORT_A  SMOKELSCUR_A  SMOKELSEV_A  \
# 26574         2             3          1           NaN            2
# 17875         2             3          1           NaN            2
# 9642          2             3          1           NaN            2
# 21932         1             2          2           NaN            2
# 27903         2             3          3           NaN            2
#
#        PIPECUR_A  PIPEEV_A  CIGAR30D_A  CIGARCUR_A  CIGAREV_A  ECIGNOW_A  \
# 26574        NaN         2         NaN         NaN          2        NaN
# 17875        3.0         1         0.0         3.0          1        NaN
# 9642         NaN         2         NaN         NaN          2        NaN
# 21932        NaN         2         NaN         NaN          2        NaN
# 27903        NaN         2         0.0         3.0          1        NaN
#
#        ECIGEV_A  CIG30D_A  SMK30D_A  CIGNOW_A  SMKNOW_A  SMKEV_A  TSTSMLAST_A  \
# 26574         2       NaN       NaN       NaN       NaN        2          NaN
# 17875         2       NaN       NaN       NaN       NaN        2          NaN
# 9642          2       NaN       NaN       NaN       NaN        2          NaN
# 21932         2       NaN       NaN       NaN       NaN        2          NaN
# 27903         2       NaN       NaN       NaN       NaN        2          NaN
#
#        TSTSMHP_A  TASTEUNW_A  TASTEFLAV_A  TASTECOMP_A  TASTEDF_A  SMELLPHT_A  \
# 26574        2.0           2            3            3          5           2
# 17875        2.0           2            3            1          1           2
# 9642         NaN           2            3            3          1           2
# 21932        NaN           2            3            3          1           2
# 27903        NaN           2            3            3          1           2
#
#        SMELLCOMP_A  SMELLDF_A  INJREDUCE_A  INJSTOPCHG_A  INJFUTWRK_A  \
# 26574            3          5          NaN           NaN          NaN
# 17875            2          1          NaN           NaN          NaN
# 9642             3          1          NaN           NaN          NaN
# 21932            3          1          NaN           NaN          NaN
# 27903            1          1          NaN           NaN          NaN
#
#        INJSTITCH_A  INJBONES_A  INJHOSP_A  INJER_A  INJSAWDOC_A  INJCHORES_A  \
# 26574          NaN         NaN        NaN      NaN          NaN          NaN
# 17875          NaN         NaN        NaN      NaN          NaN          NaN
# 9642           NaN         NaN        NaN      NaN          NaN          NaN
# 21932          NaN         NaN        NaN      NaN          NaN          NaN
# 27903          NaN         NaN        NaN      NaN          NaN          NaN
#
#        INJMVTYPE5_A  INJMVTYPE4_A  INJMVTYPE3_A  INJMVTYPE2_A  INJMVTYPE1_A  \
# 26574           NaN           NaN           NaN           NaN           NaN
# 17875           NaN           NaN           NaN           NaN           NaN
# 9642            NaN           NaN           NaN           NaN           NaN
# 21932           NaN           NaN           NaN           NaN           NaN
# 27903           NaN           NaN           NaN           NaN           NaN
#
#        INJMOTOR_A  INJFALLWRK_A  INJFALLHOM_A  INJFALL_A  INJSPORTS_A  \
# 26574         NaN           NaN           NaN        NaN          NaN
# 17875         NaN           NaN           NaN        NaN          NaN
# 9642          NaN           NaN           NaN        NaN          NaN
# 21932         NaN           NaN           NaN        NaN          NaN
# 27903         NaN           NaN           NaN        NaN          NaN
#
#        INJWORK_A  INJHOME_A  INJLIMIT_A  ANYINJURY_A  REPWRKCAUS_A  \
# 26574        NaN        NaN         NaN            2           NaN
# 17875        NaN        NaN         NaN            2           NaN
# 9642         NaN        NaN         NaN            2           NaN
# 21932        NaN        NaN         NaN            2           NaN
# 27903        NaN        NaN         NaN            2           NaN
#
#        REPREDUCE_A  REPSTOPCHG_A  REPFUTWRK_A  REPSAWDOC_A  REPLIMIT_A  \
# 26574          NaN           NaN          NaN          NaN         NaN
# 17875          NaN           NaN          NaN          NaN         NaN
# 9642           NaN           NaN          NaN          NaN         NaN
# 21932          NaN           NaN          NaN          NaN         NaN
# 27903          NaN           NaN          NaN          NaN         2.0
#
#        REPSTRAIN_A  PAITOOTH3M_A  PAIAPG3M_A  PAIHDFC3M_A  PAILLMB3M_A  \
# 26574            2           1.0         2.0          2.0          1.0
# 17875            2           1.0         1.0          1.0          1.0
# 9642             2           NaN         NaN          NaN          NaN
# 21932            2           1.0         1.0          1.0          1.0
# 27903            1           NaN         NaN          NaN          NaN
#
#        PAIULMB3M_A  PAIBACK3M_A  PAIAFFM3M_A  PAIWKLM3M_A  PAIAMNT_A  \
# 26574          4.0          3.0          2.0          2.0        3.0
# 17875          2.0          3.0          2.0          2.0        2.0
# 9642           NaN          NaN          NaN          NaN        NaN
# 21932          2.0          2.0          1.0          1.0        1.0
# 27903          NaN          NaN          NaN          NaN        NaN
#
#        PAIFRQ3M_A  WORTHLESS_A  EFFORT_A  HOPELESS_A  RESTLESS_A  NERVOUS_A  \
# 26574           4            5         5           5           3          4
# 17875           2            5         5           5           4          4
# 9642            1            5         5           5           5          5
# 21932           2            5         3           3           2          3
# 27903           1            5         3           5           5          4
#
#        SAD_A  MHTHND_A  MHTHDLY_A  MHTPYNOW_A  MHTHRPY_A  MHRX_A  DEPLEVEL_A  \
# 26574      5         2          2         NaN          2     2.0         NaN
# 17875      5         2          2         NaN          2     2.0         1.0
# 9642       5         2          2         NaN          2     2.0         NaN
# 21932      3         2          2         1.0          1     2.0         3.0
# 27903      4         2          1         NaN          2     NaN         3.0
#
#        DEPMED_A  DEPFREQ_A  ANXLEVEL_A  ANXMED_A  ANXFREQ_A  FAMCARECVD_A  \
# 26574         2          5         1.0         2          2           NaN
# 17875         2          4         1.0         2          4           NaN
# 9642          2          5         NaN         2          5           NaN
# 21932         2          2         2.0         2          1           NaN
# 27903         1          4         1.0         2          2           NaN
#
#        FAMCAREDNG_A  FAMCARE12M_A  HOMECAREDG_A  HOMEHC12M_A  TRAVEL_A  \
# 26574             2             2             2            2         1
# 17875             2             2             2            2         2
# 9642              2             2             2            2         2
# 21932             2             2             2            2         2
# 27903             2             2             2            2         1
#
#        WRKHLTHFC_A  WORKHEALTH_A  LIVEHEP_A  SHTHEPA_A  SHTHEPB_A  TDAPPREG_A  \
# 26574          2.0             2        2.0          2          1         NaN
# 17875          2.0             2        2.0          2          2         NaN
# 9642           2.0             2        1.0          2          2         NaN
# 21932          2.0             2        2.0          2          2         NaN
# 27903          2.0             2        2.0          9          1         NaN
#
#        SHINGWHEN_A  SHINGRIXNB_A  SHINGRIX1_A  ZOSTAWHEN_A  ZOSTAVAX1_A  \
# 26574          NaN           2.0          1.0          NaN          2.0
# 17875          NaN           NaN          2.0          NaN          1.0
# 9642           NaN           NaN          NaN          NaN          NaN
# 21932          NaN           NaN          NaN          NaN          NaN
# 27903          NaN           NaN          NaN          NaN          NaN
#
#        SHTSHINGLE_A  SHTPNEUNB_A  SHTPNUEV_A  FLUPREG2_A  FLUPREG_A  \
# 26574           1.0          NaN           2         NaN        NaN
# 17875           1.0          2.0           1         NaN        NaN
# 9642            NaN          NaN           9         NaN        NaN
# 21932           2.0          NaN           2         NaN        NaN
# 27903           NaN          NaN           9         NaN        NaN
#
#        SHTFLUY_A  SHTFLUM_A  SHTFLU12M_A  LIVEBIRTH_A  PREGFLUYR_A  MAMNOT1_A  \
# 26574     2021.0       10.0            1          NaN          NaN        NaN
# 17875     2020.0        9.0            1          NaN          NaN        NaN
# 9642         NaN        NaN            2          NaN          NaN        NaN
# 21932        NaN        NaN            2          NaN          NaN       11.0
# 27903        NaN        NaN            2          2.0          2.0        NaN
#
#        MAMAGE1ST1_A  MAMREASON_A  MAMPAY_A  MAMWHEN_A  MAMEV_A  HYSTEV1_A  \
# 26574           3.0          1.0       1.0        1.0      1.0        2.0
# 17875           NaN          NaN       NaN        NaN      NaN        NaN
# 9642            NaN          NaN       NaN        NaN      NaN        NaN
# 21932           1.0          2.0       1.0        5.0      1.0        2.0
# 27903           3.0          1.0       1.0        1.0      1.0        2.0
#
#        CERVICNOT1_A  CERVICRES_A  TELLCERVIC_A  HPVTEST_A  PAPTEST_A  \
# 26574           NaN          2.0           2.0        2.0        1.0
# 17875           NaN          NaN           NaN        NaN        NaN
# 9642            NaN          NaN           NaN        NaN        NaN
# 21932           5.0          NaN           NaN        NaN        NaN
# 27903           NaN          2.0           2.0        9.0        1.0
#
#        CERREASON1_A  CERVICWHEN_A  CERVICEV1_A  PSASUGGEST_A  PSAREASON_A  \
# 26574           1.0           1.0          1.0           NaN          NaN
# 17875           NaN           NaN          NaN           2.0          1.0
# 9642            NaN           NaN          NaN           NaN          NaN
# 21932           NaN           NaN          2.0           NaN          NaN
# 27903           1.0           1.0          1.0           NaN          NaN
#
#        PSAWHEN_A  PSATEST_A  COLTEST6_A  COLTEST5_A  COLTEST4_A  COLTEST3_A  \
# 26574        NaN        NaN         NaN         NaN         NaN         NaN
# 17875        6.0        1.0         NaN         NaN         NaN         NaN
# 9642         NaN        2.0         NaN         NaN         NaN         NaN
# 21932        NaN        NaN         NaN         NaN         NaN         NaN
# 27903        NaN        NaN         NaN         NaN         NaN         NaN
#
#        COLTEST2_A  COLTEST1_A  COLPROB1_A  CGUARDWHE1_A  FITCOLG1_A  \
# 26574         NaN         NaN         NaN           NaN         NaN
# 17875         NaN         NaN         2.0           6.0         NaN
# 9642          NaN         NaN         2.0           NaN         NaN
# 21932         NaN         NaN         NaN           NaN         NaN
# 27903         NaN         NaN         NaN           NaN         NaN
#
#        COLOGUARD1_A  FITHWHEN1_A  FITHEV1_A  CTCOLWHEN1_A  CTCOLEV1_A  \
# 26574           2.0          NaN        2.0           NaN         2.0
# 17875           1.0          NaN        2.0           NaN         2.0
# 9642            2.0          NaN        2.0           NaN         2.0
# 21932           2.0          NaN        2.0           NaN         2.0
# 27903           2.0          2.0        1.0           NaN         2.0
#
#        SIGWHEN_A  COLSIGWHEN_A  COLPAY_A  COLREASON_A  COLWHEN_A  \
# 26574        NaN           NaN       2.0          1.0        1.0
# 17875        6.0           NaN       9.0          1.0        6.0
# 9642         NaN           NaN       NaN          NaN        NaN
# 21932        NaN           NaN       1.0          1.0        4.0
# 27903        3.0           NaN       2.0          2.0        3.0
#
#        COLORECTYP_A  COLORECTEV_A  DIBA1CLAST_A  DIBLAST1_A  CHOLLAST_A  \
# 26574           1.0           1.0           NaN         1.0           1
# 17875           3.0           1.0           NaN         1.0           1
# 9642            NaN           2.0           NaN         1.0           1
# 21932           1.0           1.0           NaN         1.0           1
# 27903           3.0           1.0           NaN         1.0           1
#
#        BPLAST_A  RXDG12M_A  RXDL12M_A  RXLS12M_A  RXSK12M_A  RX12M_A  \
# 26574         1          2        2.0        2.0        2.0        1
# 17875         1          2        2.0        2.0        2.0        1
# 9642          1          2        NaN        NaN        NaN        2
# 21932         1          2        NaN        NaN        NaN        2
# 27903         1          2        2.0        2.0        2.0        1
#
#        CANCOVCARE_A  CANCOVOTH_A  CANCOVCHG_A  CANCOVTREA_A  VIRAPPCVD_A  \
# 26574           NaN          NaN          NaN           NaN          1.0
# 17875           2.0          1.0          NaN           2.0          NaN
# 9642            NaN          NaN          NaN           NaN          NaN
# 21932           NaN          NaN          NaN           NaN          NaN
# 27903           NaN          NaN          NaN           NaN          NaN
#
#        VIRAPP12M_A  DNGCARE_A  DLYCARE_A  MEDNG12M_A  MEDDL12M_A  HOSPONGT_A  \
# 26574            1          1          1           2           2           2
# 17875            2          2          2           2           2           2
# 9642             2          2          2           2           2           2
# 21932            2          2          2           2           2           2
# 27903            2          2          2           2           2           2
#
#        USPLKIND_A  USUALPL_A  WELLVIS_A  WELLNESS_A  LASTDR_A  CVDTSTREC_A  \
# 26574         1.0          1        NaN         1.0         1          1.0
# 17875         1.0          1        1.0         2.0         1          NaN
# 9642          1.0          1        NaN         1.0         1          NaN
# 21932         4.0          1        1.0         2.0         1          NaN
# 27903         1.0          1        NaN         1.0         1          NaN
#
#        CVDSYMTST_A  CVDSMREC_A  CVDSYMSM_A  CVDSEV_A  CVDRSLT_A  COVIDTEST_A  \
# 26574          1.0         1.0         1.0       3.0        1.0            1
# 17875          NaN         NaN         NaN       NaN        2.0            1
# 9642           NaN         NaN         NaN       NaN        2.0            1
# 21932          NaN         NaN         NaN       NaN        2.0            1
# 27903          NaN         NaN         NaN       NaN        2.0            1
#
#        CVDDIAG_A  PAYWORRY_A  PAYNOBLLNW_A  PAYBLL12M_A  HINOTMYR_A  \
# 26574          1           2           NaN            2         NaN
# 17875          2           3           NaN            2         NaN
# 9642           2           3           NaN            2         NaN
# 21932          2           3           NaN            2         NaN
# 27903          2           2           NaN            2         NaN
#
#        HINOTYR_A  RSNHIOTH_A  RSNHIWAIT_A  RSNHIMEET_A  RSNHICONF_A  \
# 26574        2.0         NaN          NaN          NaN          NaN
# 17875        2.0         NaN          NaN          NaN          NaN
# 9642         2.0         NaN          NaN          NaN          NaN
# 21932        2.0         NaN          NaN          NaN          NaN
# 27903        2.0         NaN          NaN          NaN          NaN
#
#        RSNHIELIG_A  RSNHIWANT_A  RSNHICOST_A  HISTOPELIG_A  HISTOPCOST_A  \
# 26574          NaN          NaN          NaN           NaN           NaN
# 17875          NaN          NaN          NaN           NaN           NaN
# 9642           NaN          NaN          NaN           NaN           NaN
# 21932          NaN          NaN          NaN           NaN           NaN
# 27903          NaN          NaN          NaN           NaN           NaN
#
#        HISTOPAGE_A  HISTOPMISS_A  HISTOPJOB_A  HILASTMY_A  HILAST_A  \
# 26574          NaN           NaN          NaN         NaN       NaN
# 17875          NaN           NaN          NaN         NaN       NaN
# 9642           NaN           NaN          NaN         NaN       NaN
# 21932          NaN           NaN          NaN         NaN       NaN
# 27903          NaN           NaN          NaN         NaN       NaN
#
#        MILSPC3_A  MILSPC2_A  MILSPC1_A  OGHDHP_A  OGDEDUC_A  OGPREM_A  \
# 26574        NaN        NaN        NaN       NaN        NaN       NaN
# 17875        NaN        NaN        NaN       NaN        NaN       NaN
# 9642         NaN        NaN        NaN       NaN        NaN       NaN
# 21932        2.0        1.0        2.0       NaN        NaN       NaN
# 27903        NaN        NaN        NaN       NaN        NaN       NaN
#
#        OGXCHNG_A  OPHDHP_A  OPDEDUC_A  OPPREM_A  OPXCHNG_A  CHHDHP_A  \
# 26574        NaN       NaN        NaN       NaN        NaN       NaN
# 17875        NaN       NaN        NaN       NaN        NaN       NaN
# 9642         NaN       NaN        NaN       NaN        NaN       NaN
# 21932        NaN       NaN        NaN       NaN        NaN       NaN
# 27903        NaN       NaN        NaN       NaN        NaN       NaN
#
#        CHDEDUC_A  CHPREM_A  CHXCHNG_A  PRVSCOV2_A  PRVSCOV1_A  PRDNCOV2_A  \
# 26574        NaN       NaN        NaN         NaN         2.0         NaN
# 17875        NaN       NaN        NaN         NaN         NaN         NaN
# 9642         NaN       NaN        NaN         NaN         2.0         NaN
# 21932        NaN       NaN        NaN         NaN         NaN         NaN
# 27903        NaN       NaN        NaN         NaN         2.0         NaN
#
#        PRDNCOV1_A  PRRXCOV2_A  PRRXCOV1_A  HSAHRA2_A  HSAHRA1_A  PRHDHP2_A  \
# 26574         1.0         NaN         1.0        NaN        2.0        NaN
# 17875         NaN         NaN         NaN        NaN        NaN        NaN
# 9642          2.0         NaN         9.0        NaN        2.0        NaN
# 21932         NaN         NaN         NaN        NaN        NaN        NaN
# 27903         2.0         NaN         1.0        NaN        NaN        NaN
#
#        PRHDHP1_A  PRDEDUC2_A  PRDEDUC1_A  PLN2PAY6_A  PLN2PAY5_A  PLN2PAY4_A  \
# 26574        2.0         NaN         1.0         NaN         NaN         NaN
# 17875        NaN         NaN         NaN         NaN         NaN         NaN
# 9642         2.0         NaN         1.0         NaN         NaN         NaN
# 21932        NaN         NaN         NaN         NaN         NaN         NaN
# 27903        1.0         NaN         1.0         NaN         NaN         NaN
#
#        PLN2PAY3_A  PLN2PAY2_A  PLN2PAY1_A  PLN1PAY6_A  PLN1PAY5_A  PLN1PAY4_A  \
# 26574         NaN         NaN         NaN         2.0         2.0         2.0
# 17875         NaN         NaN         NaN         NaN         NaN         NaN
# 9642          NaN         NaN         NaN         2.0         2.0         2.0
# 21932         NaN         NaN         NaN         NaN         NaN         NaN
# 27903         NaN         NaN         NaN         2.0         2.0         2.0
#
#        PLN1PAY3_A  PLN1PAY2_A  PLN1PAY1_A  PLNEXCHG2_A  PLNEXCHG1_A  \
# 26574         2.0         2.0         1.0          NaN          NaN
# 17875         NaN         NaN         NaN          NaN          NaN
# 9642          2.0         2.0         1.0          NaN          2.0
# 21932         NaN         NaN         NaN          NaN          NaN
# 27903         2.0         1.0         1.0          NaN          NaN
#
#        PRPOLH2_A  PRPOLH1_A  PRPLCOV2_A  PRPLCOV1_A  POLHLD2_A  POLHLD1_A  \
# 26574        NaN        NaN         NaN         2.0        NaN        1.0
# 17875        NaN        NaN         NaN         NaN        NaN        NaN
# 9642         NaN        NaN         NaN         2.0        NaN        1.0
# 21932        NaN        NaN         NaN         NaN        NaN        NaN
# 27903        NaN        2.0         NaN         NaN        NaN        2.0
#
#        MAHDHP_A  MADEDUC_A  MAPREM_A  MAXCHNG_A  MCPARTD_A  MCHMO_A  \
# 26574       NaN        NaN       NaN        NaN        NaN      NaN
# 17875       NaN        9.0       1.0        2.0        1.0      2.0
# 9642        NaN        NaN       NaN        NaN        NaN      NaN
# 21932       NaN        NaN       NaN        NaN        2.0      2.0
# 27903       NaN        NaN       NaN        NaN        NaN      NaN
#
#        MCCHOICE_A  MCPART_A  SINCOVRX_A  SINCOVVS_A  SINCOVDE_A  MCAIDPRB_A  \
# 26574         NaN       NaN           2           2           2         NaN
# 17875         2.0       3.0           1           2           1         NaN
# 9642          NaN       NaN           2           2           2         NaN
# 21932         2.0       3.0           2           2           2         NaN
# 27903         NaN       NaN           2           1           1         NaN
#
#        MCAREPRB_A  HIKIND10_A  HIKIND09_A  HIKIND08_A  HIKIND07_A  HIKIND06_A  \
# 26574         NaN           2           2           2           2           2
# 17875         NaN           2           2           2           2           2
# 9642          NaN           2           2           2           2           2
# 21932         NaN           2           2           2           2           1
# 27903         NaN           2           2           2           2           2
#
#        HIKIND05_A  HIKIND04_A  HIKIND03_A  HIKIND02_A  HIKIND01_A  HICOV_A  \
# 26574           2           2           2           2           1        1
# 17875           2           1           2           1           2        1
# 9642            2           2           2           2           1        1
# 21932           2           2           2           1           2        1
# 27903           2           2           2           2           1        1
#
#        DEVDONSET_A  SOCWRKLIM_A  SOCSCLPAR_A  SOCERRNDS_A  UPPOBJCT_A  \
# 26574          NaN            1            1            1           1
# 17875          NaN            2            1            1           1
# 9642           NaN            2            1            1           1
# 21932          NaN            1            3            1           1
# 27903          NaN            2            1            1           1
#
#        UPPRAISE_A  UPPSLFCR_A  COGAMTDFF_A  COGFRQDFF_A  COGTYPEDFF_A  \
# 26574           1           1          NaN          NaN           NaN
# 17875           1           1          NaN          NaN           NaN
# 9642            1           1          NaN          NaN           NaN
# 21932           1           1          1.0          1.0           3.0
# 27903           1           1          NaN          NaN           NaN
#
#        COGMEMDFF_A  COMUSESL_A  COMDIFF_A  EQSTEPS_A  EQWLK13M_A  EQWLK100_A  \
# 26574            1           2          1        NaN         NaN         NaN
# 17875            1           2          2        NaN         NaN         NaN
# 9642             1           2          1        NaN         NaN         NaN
# 21932            2           2          2        NaN         NaN         NaN
# 27903            1           2          1        NaN         NaN         NaN
#
#        NOEQSTEPS_A  NOEQWLK13M_A  NOEQWLK100_A  PERASST_A  WCHAIR_A  \
# 26574          NaN           NaN           NaN        NaN       NaN
# 17875          NaN           NaN           NaN        NaN       NaN
# 9642           NaN           NaN           NaN        NaN       NaN
# 21932          NaN           NaN           NaN        NaN       NaN
# 27903          NaN           NaN           NaN        NaN       NaN
#
#        CANEWLKR_A  STEPS_A  WLK13M_A  WLK100_A  EQUIP_A  DIFF_A  HEARNYRM_A  \
# 26574         NaN      1.0       1.0       1.0        2       1         2.0
# 17875         NaN      1.0       1.0       1.0        2       1         2.0
# 9642          NaN      1.0       1.0       1.0        2       1         1.0
# 21932         NaN      1.0       1.0       1.0        2       1         2.0
# 27903         NaN      1.0       1.0       1.0        2       1         3.0
#
#        HEARQTRM_A  HEARINGDF_A  HEARAIDFR_A  HEARAID_A  VISIONDF_A  \
# 26574         1.0            2          NaN          2           2
# 17875         1.0            2          1.0          1           1
# 9642          1.0            1          NaN          2           1
# 21932         1.0            2          NaN          2           1
# 27903         1.0            1          NaN          2           1
#
#        WEARGLSS_A  PREGNOW_A  DXSKIN_A  CURSKIN_A  DXFOOD_A  CURFOOD_A  \
# 26574           1        NaN       NaN          2       NaN          2
# 17875           1        NaN       NaN          2       NaN          2
# 9642            2        NaN       NaN          2       NaN          2
# 21932           1        NaN       NaN          2       NaN          2
# 27903           1        2.0       NaN          2       NaN          2
#
#        DXRESP_A  CURRESP_A  EPIDR_A  EPIMED_A  EPIEV_A  HLTHCOND_A  \
# 26574       1.0          1      NaN       NaN        2           2
# 17875       NaN          2      NaN       NaN        2           2
# 9642        NaN          2      NaN       NaN        2           2
# 21932       1.0          1      NaN       NaN        2           2
# 27903       NaN          2      NaN       NaN        2           2
#
#        MEDRXTRT_A  DRYMTH12M_A  COLDFLU12M_A  CFSNOW_A  CFSEV_A  LIVEREV_A  \
# 26574           2            2             2       NaN        2          2
# 17875           2            2             2       NaN        2          2
# 9642            2            2             2       NaN        2          2
# 21932           2            2             2       NaN        2          2
# 27903           1            2             2       NaN        2          2
#
#        HEPEV_A  KIDWEAKEV_A  DEPEV_A  ANXEV_A  DEMENEV_A  ARTHEV_A  COPDEV_A  \
# 26574        2            2        2        2          2         2         2
# 17875        2            2        2        2          2         2         2
# 9642         2            2        2        2          2         2         2
# 21932        2            2        1        1          2         2         2
# 27903        2            2        2        2          2         2         2
#
#        DIBCSTRESS_A  DIBSTRESS_A  DIBTYPE_A  INSDLY12M_A  INSLESS12M_A  \
# 26574           NaN          NaN        NaN          NaN           NaN
# 17875           NaN          NaN        NaN          NaN           NaN
# 9642            NaN          NaN        NaN          NaN           NaN
# 21932           NaN          NaN        NaN          NaN           NaN
# 27903           NaN          NaN        NaN          NaN           NaN
#
#        INSSKIP12M_A  DIBINSSTYR_A  DIBINSSTOP_A  DIBINSTIME_A  DIBINS_A  \
# 26574           NaN           NaN           NaN           NaN       NaN
# 17875           NaN           NaN           NaN           NaN       NaN
# 9642            NaN           NaN           NaN           NaN       NaN
# 21932           NaN           NaN           NaN           NaN       2.0
# 27903           NaN           NaN           NaN           NaN       NaN
#
#        DIBPILL_A  DIBEV_A  GESDIB_A  PREDIB_A  CANEV_A  ASER12M_A  ASAT12M_A  \
# 26574        NaN        2       2.0         2        2        NaN        NaN
# 17875        NaN        2       NaN         2        1        NaN        NaN
# 9642         NaN        2       NaN         2        2        NaN        NaN
# 21932        2.0        2       2.0         1        2        NaN        NaN
# 27903        NaN        2       2.0         2        2        NaN        NaN
#
#        ASTILL_A  ASEV_A  STREV_A  MIEV_A  ANGEV_A  CHDEV_A  CHLMED_A  \
# 26574       NaN       2        2       2        2        2       NaN
# 17875       NaN       2        2       2        2        2       NaN
# 9642        NaN       2        2       2        2        2       NaN
# 21932       NaN       2        2       2        2        2       2.0
# 27903       NaN       2        2       2        2        2       NaN
#
#        CHL12M_A  CHLEV_A  HYPMED_A  HYP12M_A  HYPDIF_A  HYPEV_A  PHSTAT_A  \
# 26574       NaN        2       NaN       NaN       NaN        2         3
# 17875       NaN        2       1.0       NaN       2.0        1         2
# 9642        NaN        2       NaN       NaN       NaN        2         2
# 21932       1.0        1       NaN       NaN       NaN        2         3
# 27903       NaN        2       NaN       NaN       NaN        2         3
#
#        PROXYREL_A  PROXY_A  AVAIL_A  HHSTAT_A  INTV_MON  RECTYPE  IMPNUM_A  \
# 26574         NaN      NaN        1         1        11       10         1
# 17875         NaN      NaN        1         1         8       10         1
# 9642          NaN      NaN        1         1         4       10         1
# 21932         NaN      NaN        1         1        10       10         1
# 27903         NaN      NaN        1         1        12       10         1
#
#          WTFA_A      HHX  POVRATTC_A
# 26574  4623.916  H028943        8.65
# 17875  7943.399  H011224        3.64
# 9642   2718.371  H059464        4.45
# 21932  3602.730  H021142        2.41
# 27903  9048.176  H063766        5.71

# %%
cancer_data = raw_data[raw_data.PROSTCAN_A.notna()]
cancer_data.shape
# Out:
# (1546, 622)

# %%
missing_pct = cancer_data.isna().mean()
low_missingness_columns = missing_pct[missing_pct == 0].index
cancer_reduced_missing = cancer_data[low_missingness_columns]
cancer_reduced_missing.shape
# Out:
# (1546, 216)

# %%
cancer_reduced_missing.sample(5)
# Out:
#        URBRRL  RATCAT_A  IMPINCFLG_A  PPSU  PSTRAT  HISPALLP_A  RACEALLP_A  \
# 1167        1        14            2    57     105           2           1
# 9859        4        14            0     1     122           2           1
# 19041       4         7            2    45     122           2           1
# 15163       1        14            0     3     137           2           1
# 9147        4         6            1    30     149           5           4
#
#        DISAB3_A  K6SPD_A  CITZNSTP_A  LEGMSTAT_A  MARSTAT_A  PCNTADTWFP_A  \
# 1167          2        2           1           3          1             0
# 9859          1        2           1           5          4             1
# 19041         2        2           1           4          7             0
# 15163         2        2           1           3          1             0
# 9147          2        2           1           4          7             0
#
#        PCNTADTWKP_A  FDSCAT4_A  FDSCAT3_A  EMPWRKLSW1_A  SMKECIGST_A  \
# 1167              0          1          1             2            3
# 9859              1          1          1             1            3
# 19041             0          1          1             2            3
# 15163             0          1          1             2            3
# 9147              0          1          1             2            3
#
#        SMKCIGST_A  BMICAT_A  WEIGHTLBTC_A  HEIGHTTC_A  URGNT12MTC_A  \
# 1167            3         2           150          68             0
# 9859            2         4           218          68             0
# 19041           4         4           996          96             0
# 15163           4         2           170          72             0
# 9147            3         2           150          68             2
#
#        EMERG12MTC_A  PCNT18UPTC  PCNTLT18TC  LSATIS4R_A  LSATIS11R_A  \
# 1167              0           2           0           1            9
# 9859              0           1           0           2            8
# 19041             1           1           0           1            7
# 15163             0           2           0           1            9
#        AGEP_A  ASTATNEW  HOUTENURE_A  HOUYRSLIV_A  FDSBALANCE_A  FDSLAST_A  \
# 1167       76         1            1            5             3          3
# 9859       85         1            1            5             3          3
# 19041      52         1            1            2             3          3
# 15163      77         1            1            5             3          3
# 9147       73         1            3            4             3          3
#
#        FDSRUNOUT_A  FSNAP12M_A  INCINTER_A  INCWRKO_A  SCHCURENR_A  \
# 1167             3           2           1          1            2
# 9859             3           2           2          1            2
# 19041            3           2           1          2            2
# 15163            3           2           1          2            2
# 9147             3           2           2          2            2
#
#        NATUSBORN_A  AFVET_A  MARITAL_A  ORIENT_A  CMPSUPPORT_A  SUPPORT_A  \
# 1167             1        1          1         2             3          2
# 9859             1        1          3         2             3          3
# 19041            1        2          3         2             1          1
# 15163            1        1          1         2             3          1
# 9147             1        2          3         2             3          2
#
#        SMOKELSEV_A  PIPEEV_A  CIGAREV_A  ECIGEV_A  SMKEV_A  TASTEUNW_A  \
# 1167             2         1          9         2        1           2
# 9859             2         2          1         2        1           2
# 19041            2         2          2         2        2           2
# 15163            2         2          2         2        2           2
# 9147             2         2          2         2        1           2
#
#        TASTEFLAV_A  TASTECOMP_A  TASTEDF_A  SMELLPHT_A  SMELLCOMP_A  \
# 1167             3            3          1           2            3
# 9859             3            3          1           2            3
# 19041            3            9          1           2            2
# 15163            3            3          1           2            3
# 9147             3            3          1           2            3
#
#        SMELLDF_A  ANYINJURY_A  REPSTRAIN_A  PAIFRQ3M_A  WORTHLESS_A  EFFORT_A  \
# 1167           1            2            2           2            5         5
# 9859           1            2            2           2            5         5
# 19041          1            1            2           3            5         2
# 15163          1            2            2           2            5         5
# 9147           1            2            2           1            5         4
#
#        HOPELESS_A  RESTLESS_A  NERVOUS_A  SAD_A  MHTHND_A  MHTHDLY_A  \
# 1167            5           5          3      5         2          2
# 9859            5           5          5      5         2          2
# 19041           5           3          3      5         2          2
# 15163           5           5          4      5         2          2
# 9147            5           5          4      3         2          2
#
#        MHTHRPY_A  DEPMED_A  DEPFREQ_A  ANXMED_A  ANXFREQ_A  FAMCAREDNG_A  \
# 1167           2         2          5         1          2             2
# 9859           2         2          4         2          4             2
# 19041          2         2          4         2          2             2
# 15163          2         2          4         2          4             2
# 9147           2         2          5         2          5             2
#
#        FAMCARE12M_A  HOMECAREDG_A  HOMEHC12M_A  TRAVEL_A  WORKHEALTH_A  \
# 1167              2             2            2         1             2
# 9859              2             2            2         2             2
# 19041             2             2            2         2             2
# 15163             2             2            2         2             2
# 9147              1             2            1         2             2
#
#        SHTHEPA_A  SHTHEPB_A  SHTPNUEV_A  SHTFLU12M_A  CHOLLAST_A  BPLAST_A  \
# 1167           9          9           1            1           1         1
# 9859           2          1           1            1           1         1
# 19041          2          2           2            2           1         1
# 15163          2          2           1            1           1         1
# 9147           2          2           1            1           1         1
#
#        RXDG12M_A  RX12M_A  CANCOVOTH_A  CANCOVTREA_A  VIRAPP12M_A  DNGCARE_A  \
# 1167           2        1          2.0           2.0            1          2
# 9859           2        1          2.0           2.0            2          2
# 19041          2        1          2.0           2.0            2          2
# 15163          2        1          2.0           2.0            2          2
# 9147           2        1          2.0           2.0            2          2
#
#        DLYCARE_A  MEDNG12M_A  MEDDL12M_A  HOSPONGT_A  USUALPL_A  LASTDR_A  \
# 1167           2           2           2           2          1         1
# 9859           2           2           2           2          1         1
# 19041          1           2           2           2          1         1
# 15163          2           2           2           2          1         1
# 9147           2           2           2           2          1         1
#
#        COVIDTEST_A  CVDDIAG_A  PAYWORRY_A  PAYBLL12M_A  SINCOVRX_A  \
# 1167             1          2           3            2           2
# 9859             1          2           2            2           2
# 19041            2          2           2            2           2
# 15163            2          2           3            2           1
# 9147             2          2           1            2           2
#
#        SINCOVVS_A  SINCOVDE_A  HIKIND10_A  HIKIND09_A  HIKIND08_A  HIKIND07_A  \
# 1167            2           2           2           2           2           2
# 9859            2           2           2           2           2           2
# 19041           1           2           2           2           2           2
# 15163           2           2           2           2           2           2
# 9147            2           2           2           2           2           1
#
#        HIKIND06_A  HIKIND05_A  HIKIND04_A  HIKIND03_A  HIKIND02_A  HIKIND01_A  \
# 1167            2           2           2           2           1           1
# 9859            2           2           2           2           1           2
# 19041           2           2           2           2           2           1
# 15163           2           2           2           2           1           1
# 9147            2           2           2           1           1           2
#
#        HICOV_A  SOCWRKLIM_A  SOCSCLPAR_A  SOCERRNDS_A  UPPOBJCT_A  UPPRAISE_A  \
# 1167         1            2            1            1           1           1
# 9859         1            2            1            1           1           1
# 19041        1            2            1            1           1           1
# 15163        1            2            1            1           1           1
# 9147         1            2            2            2           1           1
#
#        UPPSLFCR_A  COGMEMDFF_A  COMUSESL_A  COMDIFF_A  EQUIP_A  DIFF_A  \
# 1167            1            2           2          1        2       1
# 9859            2            1           2          2        2       2
# 19041           1            1           2          1        2       1
# 15163           1            1           2          1        2       1
# 9147            1            2           2          1        1       1
#
#        HEARINGDF_A  HEARAID_A  VISIONDF_A  WEARGLSS_A  CURSKIN_A  CURFOOD_A  \
# 1167             2          1           1           1          2          2
# 9859             3          2           1           2          2          2
# 19041            1          2           1           1          2          2
# 15163            1          2           1           1          2          2
# 9147             1          2           2           2          2          2
#
#        CURRESP_A  EPIEV_A  HLTHCOND_A  MEDRXTRT_A  DRYMTH12M_A  COLDFLU12M_A  \
# 1167           1        2           2           2            1             2
# 9859           1        2           2           2            2             2
# 19041          1        2           2           2            2             2
# 15163          2        2           2           2            2             2
# 9147           1        2           2           2            2             2
#
#        CFSEV_A  LIVEREV_A  HEPEV_A  KIDWEAKEV_A  DEPEV_A  ANXEV_A  DEMENEV_A  \
# 1167         2          2        2            2        2        2          2
# 9859         2          2        2            2        2        2          2
# 19041        2          2        2            2        2        2          2
# 15163        2          2        2            2        2        2          2
# 9147         2          2        2            2        2        2          2
#
#        ARTHEV_A  COPDEV_A  DIBEV_A  PREDIB_A  CANEV_A  ASEV_A  STREV_A  \
# 1167          1         2        2         2        1       2        2
# 9859          2         1        2         1        1       2        2
# 19041         2         2        2         2        1       2        2
# 15163         2         2        2         2        1       2        2
# 9147          1         2        1         2        1       2        2
#
#        MIEV_A  ANGEV_A  CHDEV_A  CHLEV_A  HYPEV_A  PHSTAT_A  AVAIL_A  \
# 1167        2        2        2        2        2         2        1
# 9859        2        2        2        1        1         3        1
# 19041       2        2        2        2        1         3        1
# 15163       2        2        2        1        2         3        1
# 9147        2        2        1        2        1         4        1
#
#        HHSTAT_A  INTV_MON  RECTYPE  IMPNUM_A    WTFA_A      HHX  POVRATTC_A
# 1167          1         1       10         1  6710.432  H049151        9.58
# 9859          1         5       10         1  4231.082  H023205        6.44
# 19041         1         8       10         1  3543.841  H015430        1.85
# 15163         1         7       10         1  7947.918  H046991        6.39
# 9147          1         4       10         1  3487.184  H040774        1.61

# %%
print("Number of unique values in column HHX", cancer_reduced_missing.HHX.nunique())
cancer_reduced_missing = cancer_reduced_missing.drop(["HHX"], axis="columns")
print("Shape of data after removing column HHX: ",cancer_reduced_missing.shape)
features = cancer_reduced_missing.drop(["PROSTCAN_A"], axis="columns")
print("Shape of data with only independent variables",features.shape)
# Out:
# Number of unique values in column HHX 1546
# Shape of data after removing column HHX:  (1546, 215)
# Shape of data with only independent variables (1546, 214)

# %%
['BMICAT_A','DIBEV_A','SMKCIGST_A','ASEV_A','COPDEV_A','HYPEV_A','AGEP_A','SKNNMCAN_A','OTHERCANP_A',
                      'SKNDCAN_A','MELANCAN_A','WEIGHTLBTC_A','LUNGCAN_A','LYMPHCAN_A','COLONCAN_A','HEIGHTTC_A',
                      'BLADDCAN_A','PANCRCAN_A','THROACAN_A','ESOPHCAN_A','GALLBCAN_A','BONECAN_A','LEUKECAN_A',
                      'MOUTHCAN_A','LIVERCAN_A','DEPFREQ_A','LARYNCAN_A','BREASCAN_A','REGION','ANXFREQ_A','RACEALLP',
                      'HOUYRSLIV_A','SMOKELSEV_A','PROSTCAN_A','CHDEV_A','PSATEST_A','LEGMSTAT_A','ORIENT_A','ECIGEV_A']
# Out:
#          features      variance
# 212        WTFA_A  38442.604000
# 20   WEIGHTLBTC_A    871.000000
# 3            PPSU    152.000000
# 27    LSATIS11R_A     99.000000
# 77         AGEP_A     79.000000
# 4          PSTRAT     51.000000
# 21     HEIGHTTC_A     36.000000
# 37        EDUCP_A     28.156489
# 1        RATCAT_A     12.262360
# 209      INTV_MON     11.000000
# 213    POVRATTC_A      9.680215
# 11      MARSTAT_A      5.837673
# 128     SHTHEPA_A      5.026996
# 129     SHTHEPB_A      4.234038
# 130    SHTPNUEV_A      2.256977
# 121     ANXFREQ_A      2.034706
# 93      SUPPORT_A      1.980721
# 80    HOUYRSLIV_A      1.886739
# 85     INCINTER_A      1.858084
# 108    PAIFRQ3M_A      1.751209
# 132    CHOLLAST_A      1.698793
# 90      MARITAL_A      1.658949
# 10     LEGMSTAT_A      1.464108
# 119     DEPFREQ_A      1.439308
# 105     SMELLDF_A      1.434133
# 14      FDSCAT4_A      1.416193
# 79    HOUTENURE_A      1.376300
# 86      INCWRKO_A      1.375544
# 16   EMPWRKLSW1_A      1.332210
# 74       INTV_QRT      1.313759
# 18     SMKCIGST_A      1.306627
# 15      FDSCAT3_A      1.292274
# 22   URGNT12MTC_A      1.271254
# 206      PHSTAT_A      1.268138
# 102     TASTEDF_A      1.265873
# 104   SMELLCOMP_A      1.264926
# 112    RESTLESS_A      1.244819
# 101   TASTECOMP_A      1.188510
# 110      EFFORT_A      1.119610
# 26     LSATIS4R_A      1.115953
# 89        AFVET_A      1.097389
# 100   TASTEFLAV_A      1.095074
# 88    NATUSBORN_A      1.093042
# 96      CIGAREV_A      1.070740
# 0          URBRRL      1.068869
# 9      CITZNSTP_A      1.061843
# 6      RACEALLP_A      1.060934
# 23   EMERG12MTC_A      1.047886
# 92   CMPSUPPORT_A      1.044043
# 73         REGION      1.012192
# 98        SMKEV_A      1.007506
# 36      PRIVATE_A      1.001444
# 8         K6SPD_A      0.965294
# 113     NERVOUS_A      0.965237
# 84     FSNAP12M_A      0.958397
# 95       PIPEEV_A      0.954079
# 91       ORIENT_A      0.954022
# 131   SHTFLU12M_A      0.930370
# 99     TASTEUNW_A      0.926195
# 94    SMOKELSEV_A      0.883984
# 103    SMELLPHT_A      0.875176
# 35     MEDICARE_A      0.819854
# 17    SMKECIGST_A      0.800694
# 87    SCHCURENR_A      0.785672
# 97       ECIGEV_A      0.775768
# 83    FDSRUNOUT_A      0.731828
# 106   ANYINJURY_A      0.726902
# 81   FDSBALANCE_A      0.723806
# 126      TRAVEL_A      0.723378
# 19       BMICAT_A      0.720328
# 120      ANXMED_A      0.720141
# 146   COVIDTEST_A      0.710123
# 82      FDSLAST_A      0.703296
# 207       AVAIL_A      0.701290
# 114         SAD_A      0.676478
# 107   REPSTRAIN_A      0.675927
# 118      DEPMED_A      0.642152
# 13   PCNTADTWKP_A      0.619781
# 123  FAMCARE12M_A      0.603069
# 111    HOPELESS_A      0.601484
# 138   VIRAPP12M_A      0.589501
# 148    PAYWORRY_A      0.588418
# 133      BPLAST_A      0.588276
# 32     MILITARY_A      0.578518
# 166   SOCERRNDS_A      0.572165
# 109   WORTHLESS_A      0.567598
# 117     MHTHRPY_A      0.551626
# 174        DIFF_A      0.543547
# 136   CANCOVOTH_A      0.537911
# 125   HOMEHC12M_A      0.511932
# 145      LASTDR_A      0.502894
# 116     MHTHDLY_A      0.496063
# 152    SINCOVDE_A      0.493663
# 115      MHTHND_A      0.493145
# 2     IMPINCFLG_A      0.491789
# 52     SKNNMCAN_A      0.483793
# 12   PCNTADTWFP_A      0.482387
# 151    SINCOVVS_A      0.473072
# 135       RX12M_A      0.465466
# 137  CANCOVTREA_A      0.456696
# 143    HOSPONGT_A      0.451420
# 5      HISPALLP_A      0.448877
# 127  WORKHEALTH_A      0.438831
# 140     DLYCARE_A      0.429481
# 122  FAMCAREDNG_A      0.422325
# 124  HOMECAREDG_A      0.421081
# 38      PARSTAT_A      0.418535
# 144     USUALPL_A      0.409066
# 78       ASTATNEW      0.403261
# 45    OTHERCANP_A      0.390775
# 184    MEDRXTRT_A      0.389265
# 53      SKNMCAN_A      0.385695
# 165   SOCSCLPAR_A      0.381478
# 139     DNGCARE_A      0.366697
# 42     PCNTADLT_A      0.359867
# 24     PCNT18UPTC      0.359605
# 204       CHLEV_A      0.358516
# 39   SAPARENTSC_A      0.352013
# 51     SKNDKCAN_A      0.349480
# 57     MELANCAN_A      0.348860
# 150    SINCOVRX_A      0.348633
# 183    HLTHCOND_A      0.348586
# 46     COLRCCAN_A      0.347618
# 65     COLONCAN_A      0.342618
# 175   HEARINGDF_A      0.338794
# 70     BLADDCAN_A      0.336292
# 134     RXDG12M_A      0.333629
# 149   PAYBLL12M_A      0.328476
# 58     LYMPHCAN_A      0.324042
# 59      LUNGCAN_A      0.320110
# 203       CHDEV_A      0.314030
# 47     HDNCKCAN_A      0.308808
# 170   COGMEMDFF_A      0.307544
# 61     LEUKECAN_A      0.306114
# 48     THYROCAN_A      0.304084
# 49     THROACAN_A      0.300003
# 147     CVDDIAG_A      0.299899
# 68      BONECAN_A      0.294513
# 67     BRAINCAN_A      0.291749
# 56     MOUTHCAN_A      0.291749
# 60     LIVERCAN_A      0.291055
# 69     BLOODCAN_A      0.291055
# 54     RECTUCAN_A      0.290361
# 64     ESOPHCAN_A      0.290361
# 55     PANCRCAN_A      0.288970
# 50     STOMACAN_A      0.288970
# 177    VISIONDF_A      0.288235
# 142    MEDDL12M_A      0.287178
# 164   SOCWRKLIM_A      0.287015
# 66     BREASCAN_A      0.286878
# 62     LARYNCAN_A      0.286179
# 63     GALLBCAN_A      0.284778
# 181     CURRESP_A      0.283545
# 141    MEDNG12M_A      0.282594
# 162    HIKIND01_A      0.281870
# 194      ARTHEV_A      0.278484
# 161    HIKIND02_A      0.262523
# 34     MEDICAID_A      0.259469
# 197      PREDIB_A      0.248289
# 191       DEPEV_A      0.238017
# 205       HYPEV_A      0.237909
# 25     PCNTLT18TC      0.227135
# 43     PCNTKIDS_A      0.225359
# 179     CURSKIN_A      0.221369
# 44       NUMCAN_A      0.198816
# 167    UPPOBJCT_A      0.198098
# 41    OVER65FLG_A      0.197272
# 160    HIKIND03_A      0.192617
# 71      HISDETP_A      0.186583
# 169    UPPSLFCR_A      0.185145
# 196       DIBEV_A      0.183707
# 168    UPPRAISE_A      0.182786
# 192       ANXEV_A      0.178772
# 178    WEARGLSS_A      0.163763
# 7        DISAB3_A      0.152394
# 176     HEARAID_A      0.151990
# 202       ANGEV_A      0.136318
# 173       EQUIP_A      0.135995
# 200       STREV_A      0.134630
# 199        ASEV_A      0.132067
# 180     CURFOOD_A      0.131251
# 172     COMDIFF_A      0.131079
# 157    HIKIND06_A      0.130029
# 195      COPDEV_A      0.125393
# 201        MIEV_A      0.101381
# 193     DEMENEV_A      0.093954
# 159    HIKIND04_A      0.085871
# 185   DRYMTH12M_A      0.085519
# 187       CFSEV_A      0.080783
# 190   KIDWEAKEV_A      0.080763
# 189       HEPEV_A      0.065091
# 153    HIKIND10_A      0.049621
# 155    HIKIND08_A      0.047730
# 154    HIKIND09_A      0.045831
# 72         HISP_A      0.043228
# 30       OTHPUB_A      0.036216
# 31          IHS_A      0.035575
# 156    HIKIND07_A      0.035575
# 158    HIKIND05_A      0.031674
# 29       OTHGOV_A      0.031048
# 33         CHIP_A      0.023271
# 182       EPIEV_A      0.020270
# 186  COLDFLU12M_A      0.019028
# 188     LIVEREV_A      0.015909
# 28       NOTCOV_A      0.015909
# 163       HICOV_A      0.014656
# 171    COMUSESL_A      0.011507
# 40    MLTFAMFLG_A      0.009608
# 198       CANEV_A      0.000000
# 75        SRVY_YR      0.000000
# 208      HHSTAT_A      0.000000
# 210       RECTYPE      0.000000
# 211      IMPNUM_A      0.000000
# 76          SEX_A      0.000000

# %%
selector = VarianceThreshold()
selector.fit(features)

variances = pd.DataFrame({"features": features.columns, "variance":selector.variances_})
variances.sort_values(by=["variance"])
# Out:
#          features      variance
# 211      IMPNUM_A      0.000000
# 210       RECTYPE      0.000000
# 208      HHSTAT_A      0.000000
# 75        SRVY_YR      0.000000
# 76          SEX_A      0.000000
# 198       CANEV_A      0.000000
# 40    MLTFAMFLG_A      0.009608
# 171    COMUSESL_A      0.011507
# 163       HICOV_A      0.014656
# 188     LIVEREV_A      0.015909
# 28       NOTCOV_A      0.015909
# 186  COLDFLU12M_A      0.019028
# 182       EPIEV_A      0.020270
# 33         CHIP_A      0.023271
# 29       OTHGOV_A      0.031048
# 158    HIKIND05_A      0.031674
# 156    HIKIND07_A      0.035575
# 31          IHS_A      0.035575
# 30       OTHPUB_A      0.036216
# 72         HISP_A      0.043228
# 154    HIKIND09_A      0.045831
# 155    HIKIND08_A      0.047730
# 153    HIKIND10_A      0.049621
# 189       HEPEV_A      0.065091
# 190   KIDWEAKEV_A      0.080763
# 187       CFSEV_A      0.080783
# 185   DRYMTH12M_A      0.085519
# 159    HIKIND04_A      0.085871
# 193     DEMENEV_A      0.093954
# 201        MIEV_A      0.101381
# 195      COPDEV_A      0.125393
# 157    HIKIND06_A      0.130029
# 172     COMDIFF_A      0.131079
# 180     CURFOOD_A      0.131251
# 199        ASEV_A      0.132067
# 200       STREV_A      0.134630
# 173       EQUIP_A      0.135995
# 202       ANGEV_A      0.136318
# 176     HEARAID_A      0.151990
# 7        DISAB3_A      0.152394
# 178    WEARGLSS_A      0.163763
# 192       ANXEV_A      0.178772
# 168    UPPRAISE_A      0.182786
# 196       DIBEV_A      0.183707
# 169    UPPSLFCR_A      0.185145
# 71      HISDETP_A      0.186583
# 160    HIKIND03_A      0.192617
# 41    OVER65FLG_A      0.197272
# 167    UPPOBJCT_A      0.198098
# 44       NUMCAN_A      0.198816
# 179     CURSKIN_A      0.221369
# 43     PCNTKIDS_A      0.225359
# 25     PCNTLT18TC      0.227135
# 205       HYPEV_A      0.237909
# 191       DEPEV_A      0.238017
# 197      PREDIB_A      0.248289
# 34     MEDICAID_A      0.259469
# 161    HIKIND02_A      0.262523
# 194      ARTHEV_A      0.278484
# 162    HIKIND01_A      0.281870
# 141    MEDNG12M_A      0.282594
# 181     CURRESP_A      0.283545
# 63     GALLBCAN_A      0.284778
# 62     LARYNCAN_A      0.286179
# 66     BREASCAN_A      0.286878
# 164   SOCWRKLIM_A      0.287015
# 142    MEDDL12M_A      0.287178
# 177    VISIONDF_A      0.288235
# 50     STOMACAN_A      0.288970
# 55     PANCRCAN_A      0.288970
# 54     RECTUCAN_A      0.290361
# 64     ESOPHCAN_A      0.290361
# 69     BLOODCAN_A      0.291055
# 60     LIVERCAN_A      0.291055
# 56     MOUTHCAN_A      0.291749
# 67     BRAINCAN_A      0.291749
# 68      BONECAN_A      0.294513
# 147     CVDDIAG_A      0.299899
# 49     THROACAN_A      0.300003
# 48     THYROCAN_A      0.304084
# 61     LEUKECAN_A      0.306114
# 170   COGMEMDFF_A      0.307544
# 47     HDNCKCAN_A      0.308808
# 203       CHDEV_A      0.314030
# 59      LUNGCAN_A      0.320110
# 58     LYMPHCAN_A      0.324042
# 149   PAYBLL12M_A      0.328476
# 134     RXDG12M_A      0.333629
# 70     BLADDCAN_A      0.336292
# 175   HEARINGDF_A      0.338794
# 65     COLONCAN_A      0.342618
# 46     COLRCCAN_A      0.347618
# 183    HLTHCOND_A      0.348586
# 150    SINCOVRX_A      0.348633
# 57     MELANCAN_A      0.348860
# 51     SKNDKCAN_A      0.349480
# 39   SAPARENTSC_A      0.352013
# 204       CHLEV_A      0.358516
# 24     PCNT18UPTC      0.359605
# 42     PCNTADLT_A      0.359867
# 139     DNGCARE_A      0.366697
# 165   SOCSCLPAR_A      0.381478
# 53      SKNMCAN_A      0.385695
# 184    MEDRXTRT_A      0.389265
# 45    OTHERCANP_A      0.390775
# 78       ASTATNEW      0.403261
# 144     USUALPL_A      0.409066
# 38      PARSTAT_A      0.418535
# 124  HOMECAREDG_A      0.421081
# 122  FAMCAREDNG_A      0.422325
# 140     DLYCARE_A      0.429481
# 127  WORKHEALTH_A      0.438831
# 5      HISPALLP_A      0.448877
# 143    HOSPONGT_A      0.451420
# 137  CANCOVTREA_A      0.456696
# 135       RX12M_A      0.465466
# 151    SINCOVVS_A      0.473072
# 12   PCNTADTWFP_A      0.482387
# 52     SKNNMCAN_A      0.483793
# 2     IMPINCFLG_A      0.491789
# 115      MHTHND_A      0.493145
# 152    SINCOVDE_A      0.493663
# 116     MHTHDLY_A      0.496063
# 145      LASTDR_A      0.502894
# 125   HOMEHC12M_A      0.511932
# 136   CANCOVOTH_A      0.537911
# 174        DIFF_A      0.543547
# 117     MHTHRPY_A      0.551626
# 109   WORTHLESS_A      0.567598
# 166   SOCERRNDS_A      0.572165
# 32     MILITARY_A      0.578518
# 133      BPLAST_A      0.588276
# 148    PAYWORRY_A      0.588418
# 138   VIRAPP12M_A      0.589501
# 111    HOPELESS_A      0.601484
# 123  FAMCARE12M_A      0.603069
# 13   PCNTADTWKP_A      0.619781
# 118      DEPMED_A      0.642152
# 107   REPSTRAIN_A      0.675927
# 114         SAD_A      0.676478
# 207       AVAIL_A      0.701290
# 82      FDSLAST_A      0.703296
# 146   COVIDTEST_A      0.710123
# 120      ANXMED_A      0.720141
# 19       BMICAT_A      0.720328
# 126      TRAVEL_A      0.723378
# 81   FDSBALANCE_A      0.723806
# 106   ANYINJURY_A      0.726902
# 83    FDSRUNOUT_A      0.731828
# 97       ECIGEV_A      0.775768
# 87    SCHCURENR_A      0.785672
# 17    SMKECIGST_A      0.800694
# 35     MEDICARE_A      0.819854
# 103    SMELLPHT_A      0.875176
# 94    SMOKELSEV_A      0.883984
# 99     TASTEUNW_A      0.926195
# 131   SHTFLU12M_A      0.930370
# 91       ORIENT_A      0.954022
# 95       PIPEEV_A      0.954079
# 84     FSNAP12M_A      0.958397
# 113     NERVOUS_A      0.965237
# 8         K6SPD_A      0.965294
# 36      PRIVATE_A      1.001444
# 98        SMKEV_A      1.007506
# 73         REGION      1.012192
# 92   CMPSUPPORT_A      1.044043
# 23   EMERG12MTC_A      1.047886
# 6      RACEALLP_A      1.060934
# 9      CITZNSTP_A      1.061843
# 0          URBRRL      1.068869
# 96      CIGAREV_A      1.070740
# 88    NATUSBORN_A      1.093042
# 100   TASTEFLAV_A      1.095074
# 89        AFVET_A      1.097389
# 26     LSATIS4R_A      1.115953
# 110      EFFORT_A      1.119610
# 101   TASTECOMP_A      1.188510
# 112    RESTLESS_A      1.244819
# 104   SMELLCOMP_A      1.264926
# 102     TASTEDF_A      1.265873
# 206      PHSTAT_A      1.268138
# 22   URGNT12MTC_A      1.271254
# 15      FDSCAT3_A      1.292274
# 18     SMKCIGST_A      1.306627
# 74       INTV_QRT      1.313759
# 16   EMPWRKLSW1_A      1.332210
# 86      INCWRKO_A      1.375544
# 79    HOUTENURE_A      1.376300
# 14      FDSCAT4_A      1.416193
# 105     SMELLDF_A      1.434133
# 119     DEPFREQ_A      1.439308
# 10     LEGMSTAT_A      1.464108
# 90      MARITAL_A      1.658949
# 132    CHOLLAST_A      1.698793
# 108    PAIFRQ3M_A      1.751209
# 85     INCINTER_A      1.858084
# 80    HOUYRSLIV_A      1.886739
# 93      SUPPORT_A      1.980721
# 121     ANXFREQ_A      2.034706
# 130    SHTPNUEV_A      2.256977
# 129     SHTHEPB_A      4.234038
# 128     SHTHEPA_A      5.026996
# 11      MARSTAT_A      5.837673
# 213    POVRATTC_A      9.680215
# 209      INTV_MON     11.000000
# 1        RATCAT_A     12.262360
# 37        EDUCP_A     28.156489
# 21     HEIGHTTC_A     36.000000
# 4          PSTRAT     51.000000
# 77         AGEP_A     79.000000
# 27    LSATIS11R_A     99.000000
# 3            PPSU    152.000000
# 20   WEIGHTLBTC_A    871.000000
# 212        WTFA_A  38442.604000

# %%
non_zero_var_columns = variances[variances.variance > 0 ]['features'].tolist()
feature_data = features[non_zero_var_columns]
target_variable = cancer_data["PROSTCAN_A"]

# %%
feature_data.describe()
# Out:
#             URBRRL     RATCAT_A  IMPINCFLG_A         PPSU       PSTRAT  \
# count  1546.000000  1546.000000  1546.000000  1546.000000  1546.000000
# mean
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.000000     2.000000     2.000000     2.000000     2.000000
# 50%       2.000000     2.000000     2.000000     2.000000     2.000000
# 75%       2.000000     2.000000     2.000000     2.000000     2.000000
# max       9.000000     9.000000     9.000000     2.000000     9.000000
#
#            CHDEV_A      CHLEV_A      HYPEV_A     PHSTAT_A      AVAIL_A  \
# count  1546.000000  1546.000000  1546.000000  1546.000000  1546.000000
# mean      1.842173     1.487710     1.390039     2.859638     1.173997
# std       0.560565     0.598956     0.487917     1.126481     0.837702
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.000000     1.000000     1.000000     2.000000     1.000000
# 50%       2.000000     1.000000     1.000000     3.000000     1.000000
# 75%       2.000000     2.000000     2.000000     4.000000     1.000000
# max       9.000000     9.000000     2.000000     9.000000     8.000000
#
#           INTV_MON        WTFA_A   POVRATTC_A
# count  1546.000000   1546.000000  1546.000000
# mean      6.606727   7117.468750     4.946300
# std       3.527689   4058.870588     3.112311
# min       1.000000   1049.030000     0.000000
# 25%       3.000000   4211.590000     2.480000
# 50%       7.000000   6436.172500     4.150000
# 75%      10.000000   8852.124500     6.720000
# max      12.000000  39491.634000    11.000000

# %%
def convert_to_categorical(df):
    """
    Convert selected columns in a DataFrame to categorical columns if they meet the following criteria:
    - Have 14 or fewer unique numbers.
    - All non-NaN values are whole numbers without any decimals.

    Parameters:
    - df (pandas.DataFrame): The input DataFrame.

    Returns:
    pandas.DataFrame: The DataFrame with selected columns converted to categorical.
    """
    for column in df.columns:
        unique_values = df[column].dropna().unique()  # Exclude NaN values
        
        # Check if the column has 14 or fewer unique values
        if len(unique_values) <= 14:
            
            # Check if all non-NaN values are whole numbers without decimals
            if all(value == int(value) and value % 1 == 0 for value in unique_values):
                
                # Convert the column to categorical
                df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
                df[column] = df[column].astype('category')
    
    return df

def filter_non_categorical_columns(df):
    """
    Filters out all non-categorical columns from a pandas DataFrame.

    Parameters:
    - df (pd.DataFrame): The input DataFrame.

    Returns:
    pd.DataFrame: A new DataFrame containing only the non-categorical columns.
    """
    non_categorical_columns = df.select_dtypes(exclude='category').columns
    return df[non_categorical_columns]

# %%
feature_data = convert_to_categorical(feature_data)
non_cat_data = filter_non_categorical_columns(feature_data)
non_cat_data.shape
# Out:
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64')
# C:\Users\HP 10th Gen\AppData\Local\Temp\ipykernel_27528\2513540337.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype('category')
# (1546, 7)

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_data, target_variable, test_size=0.2, random_state=42, stratify=target_variable)

# %%
y_train.value_counts()/len(y_train)
# Out:
# 2.0    0.705502
# 1.0    0.288026
# 9.0    0.004854
# 7.0    0.001618
# Name: PROSTCAN_A, dtype: float64

# %%
y_test.value_counts()/len(y_test)
# Out:
# 2.0    0.706452
# 1.0    0.287097
# 9.0    0.006452
# Name: PROSTCAN_A, dtype: float64

# %%
print("Model performance without considering class imbalance")
rf = RandomForestClassifier(random_state=42)

####
rf.fit(X_train, y_train)

# Make predictions on the training set
y_train_pred = rf.predict(X_train)

# Evaluate the model using classification report
print("Classification report on the training set")
print(classification_report(y_train, y_train_pred))
####

# Make predictions on the testing set
y_test_pred = rf.predict(X_test)

# Evaluate the model using classification report
print("Classification report on the testing set")
print(classification_report(y_test, y_test_pred))
# Out:
# Model performance without considering class imbalance
# Classification report on the training set
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       356
#          2.0       1.00      1.00      1.00       872
#          7.0       1.00      1.00      1.00         2
#          9.0       1.00      1.00      1.00         6
#
#     accuracy                           1.00      1236
#    macro avg       1.00      1.00      1.00      1236
# weighted avg       1.00      1.00      1.00      1236
#
# Classification report on the testing set
#               precision    recall  f1-score   support
#
#          1.0       0.84      0.35      0.49        89
#          2.0       0.79      0.97      0.87       219
#          9.0       1.00      1.00      1.00         2
#
#     accuracy                           0.79       310
#    macro avg       0.87      0.77      0.79       310
# weighted avg       0.80      0.79      0.76       310

# %%
target_variable.value_counts()/len(target_variable)
# Out:
# 2.0    0.705692
# 1.0    0.287840
# 9.0    0.005175
# 7.0    0.001294
# Name: PROSTCAN_A, dtype: float64

# %%
len(y_train)
# Out:
# 1236

# %%
len(y_train)/y_train.value_counts()
# Out:
# 2.0      1.417431
# 1.0      3.471910
# 9.0    206.000000
# 7.0    618.000000
# Name: PROSTCAN_A, dtype: float64

# %%
print("Model performance after considering class imbalance")
rf = RandomForestClassifier(random_state=42, class_weight={1:4,2:1,9:206,7:618})
rf.fit(X_train, y_train)

# Make predictions on the training set
y_train_pred = rf.predict(X_train)

# Evaluate the model using classification report
print("Classification report on the training set")
print(classification_report(y_train, y_train_pred))

# Make predictions on the testing set
y_test_pred = rf.predict(X_test)

# Evaluate the model using classification report
print("Classification report on the testing set")
print(classification_report(y_test, y_test_pred))
# Out:
# Model performance after considering class imbalance
# Classification report on the training set
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       356
#          2.0       1.00      1.00      1.00       872
#          7.0       1.00      1.00      1.00         2
#          9.0       1.00      1.00      1.00         6
#
#     accuracy                           1.00      1236
#    macro avg       1.00      1.00      1.00      1236
# weighted avg       1.00      1.00      1.00      1236
#
# Classification report on the testing set
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.43      0.58        89
#          2.0       0.81      0.98      0.88       219
#          9.0       1.00      1.00      1.00         2
#
#     accuracy                           0.82       310
#    macro avg       0.90      0.80      0.82       310
# weighted avg       0.83      0.82      0.80       310

# %%
print("Model performance after considering class imbalance")
rf = RandomForestClassifier(random_state=42, class_weight={1:4,2:1,9:20,7:61})
rf.fit(X_train, y_train)

# Make predictions on the training set
y_train_pred = rf.predict(X_train)

# Evaluate the model using classification report
print("Classification report on the training set")
print(classification_report(y_train, y_train_pred))

# Make predictions on the testing set
y_test_pred = rf.predict(X_test)

# Evaluate the model using classification report
print("Classification report on the testing set")
print(classification_report(y_test, y_test_pred))
# Out:
# Model performance after considering class imbalance
# Classification report on the training set
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       356
#          2.0       1.00      1.00      1.00       872
#          7.0       1.00      1.00      1.00         2
#          9.0       1.00      1.00      1.00         6
#
#     accuracy                           1.00      1236
#    macro avg       1.00      1.00      1.00      1236
# weighted avg       1.00      1.00      1.00      1236
#
# Classification report on the testing set
#               precision    recall  f1-score   support
#
#          1.0       0.91      0.47      0.62        89
#          2.0       0.82      0.98      0.89       219
#          9.0       1.00      1.00      1.00         2
#
#     accuracy                           0.84       310
#    macro avg       0.91      0.82      0.84       310
# weighted avg       0.85      0.84      0.82       310

# %%
feature_importance = pd.DataFrame({"features": X_train.columns, "importance":rf.feature_importances_})
feature_importance = feature_importance.sort_values(by="importance", ascending=False)

# %%
def plot_top_features(df, top_n=20):
    # Sort the DataFrame by importance in descending order
    df_sorted = df.sort_values(by='importance', ascending=False)

    # Select the top N features
    top_features = df_sorted.head(top_n)

    # Aggregate other features into a new row called 'Others'
    other_features = df_sorted.iloc[top_n:]
    others_row = pd.DataFrame({'features': ['Others'], 'importance': [other_features['importance'].sum()]})
    df_aggregated = pd.concat([top_features, others_row])

    # Set Seaborn style
    sns.set(style="whitegrid")

    # Plot the horizontal bar chart using seaborn
    plt.figure(figsize=(12, 8))
    sns.barplot(x='importance', y='features', data=df_aggregated, color='skyblue')
    plt.xlabel('Importance', fontsize=14)
    plt.ylabel('Features', fontsize=14)
    plt.title(f'Top {top_n} Features and Others', fontsize=16)
    plt.xticks(rotation=45, ha='right', fontsize=12)
    plt.yticks(fontsize=12)
    plt.tight_layout()  # Adjust layout for better appearance
    plt.show()
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plot_top_features(feature_importance, top_n=50)

# %%
def add_cumulative_percentage(df):
    # Make sure the 'importance' column is numeric
    df['importance'] = pd.to_numeric(df['importance'], errors='coerce')

    # Calculate cumulative percentage
    df['cumulative_percentage'] = (df['importance'].cumsum() / df['importance'].sum()) * 100

    # Fill any NaN values with 0 in case there are missing values in 'importance' column
    df['cumulative_percentage'].fillna(0, inplace=True)

    return df

feature_importance = add_cumulative_percentage(feature_importance)

# %%
feature_importance.head(50)
# Out:
#          features  importance  cumulative_percentage
# 52     SKNNMCAN_A    0.054995               5.499465
# 75         AGEP_A    0.033629               8.862370
# 53      SKNMCAN_A    0.031392              12.001572
# 45    OTHERCANP_A    0.028233              14.824853
# 51     SKNDKCAN_A    0.024205              17.245384
# 44       NUMCAN_A    0.022092              19.454618
# 57     MELANCAN_A    0.018847              21.339275
# 206        WTFA_A    0.017551              23.094344
# 20   WEIGHTLBTC_A    0.017368              24.831187
# 4          PSTRAT    0.017134              26.544616
# 59      LUNGCAN_A    0.016758              28.220389
# 58     LYMPHCAN_A    0.016648              29.885228
# 46     COLRCCAN_A    0.016512              31.536468
# 47     HDNCKCAN_A    0.016067              33.143152
# 65     COLONCAN_A    0.015705              34.713664
# 207    POVRATTC_A    0.015360              36.249703
# 3            PPSU    0.014550              37.704663
# 21     HEIGHTTC_A    0.012969              39.001576
# 37        EDUCP_A    0.012176              40.219203
# 70     BLADDCAN_A    0.011835              41.402655
# 205      INTV_MON    0.011228              42.525489
# 55     PANCRCAN_A    0.010608              43.586292
# 49     THROACAN_A    0.010492              44.635458
# 64     ESOPHCAN_A    0.009906              45.626072
# 54     RECTUCAN_A    0.009423              46.568349
# 63     GALLBCAN_A    0.009370              47.505352
# 1        RATCAT_A    0.009045              48.409859
# 68      BONECAN_A    0.009040              49.313831
# 61     LEUKECAN_A    0.008936              50.207470
# 56     MOUTHCAN_A    0.008934              51.100904
# 60     LIVERCAN_A    0.008786              51.979507
# 117     DEPFREQ_A    0.008775              52.857024
# 62     LARYNCAN_A    0.007904              53.647419
# 203      PHSTAT_A    0.007585              54.405921
# 22   URGNT12MTC_A    0.007530              55.158921
# 106    PAIFRQ3M_A    0.007352              55.894149
# 0          URBRRL    0.007164              56.610574
# 181    HLTHCOND_A    0.007135              57.324101
# 50     STOMACAN_A    0.007117              58.035809
# 27    LSATIS11R_A    0.007036              58.739370
# 66     BREASCAN_A    0.007014              59.440770
# 35     MEDICARE_A    0.006822              60.123010
# 110    RESTLESS_A    0.006452              60.768161
# 73         REGION    0.006236              61.391804
# 119     ANXFREQ_A    0.006161              62.007883
# 74       INTV_QRT    0.006080              62.615880
# 6      RACEALLP_A    0.005955              63.211352
# 5      HISPALLP_A    0.005884              63.799715
# 78    HOUYRSLIV_A    0.005694              64.369151
# 92    SMOKELSEV_A    0.005251              64.894229

# %%
most_important_features = feature_importance.head(50).features.tolist()
X_train, X_test, y_train, y_test = train_test_split(feature_data[most_important_features], target_variable, test_size=0.2, random_state=42, stratify=target_variable)

# %%
print("Model performance after considering class imbalance")
rf_model = RandomForestClassifier(random_state=4212, class_weight={1:4,2:1,9:20,7:61})
rf_model.fit(X_train, y_train)

# Make predictions on the training set
y_train_pred = rf_model.predict(X_train)

# Evaluate the model using classification report
print("Classification report on the training set")
print(classification_report(y_train, y_train_pred))

# Make predictions on the testing set
y_test_pred = rf_model.predict(X_test)

# Evaluate the model using classification report
print("Classification report on the testing set")
print(classification_report(y_test, y_test_pred))
# Out:
# Model performance after considering class imbalance
# Classification report on the training set
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       356
#          2.0       1.00      1.00      1.00       872
#          7.0       1.00      1.00      1.00         2
#          9.0       1.00      1.00      1.00         6
#
#     accuracy                           1.00      1236
#    macro avg       1.00      1.00      1.00      1236
# weighted avg       1.00      1.00      1.00      1236
#
# Classification report on the testing set
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.64      0.74        89
#          2.0       0.87      0.96      0.91       219
#          9.0       1.00      1.00      1.00         2
#
#     accuracy                           0.87       310
#    macro avg       0.92      0.87      0.88       310
# weighted avg       0.87      0.87      0.86       310

# %% [markdown]
# ## Tuning hyperparameter for better performance

# %%
# Define the Random Forest Classifier
rf_classifier = RandomForestClassifier(class_weight={1:4,2:1,9:20,7:61})

# Define the hyperparameters and their possible values for tuning
param_dist = {
    'criterion': ["gini", "entropy", "log_loss"],
    'n_estimators': [int(x) for x in np.linspace(start=50, stop=200, num=10)],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4,8],
    'bootstrap': [True, False]
}

# Use F1 score as the scoring metric
scorer = make_scorer(f1_score, average='weighted')  # Adjust 'average' parameter as needed

# Use RandomizedSearchCV for hyperparameter tuning with F1 score
random_search = RandomizedSearchCV(estimator=rf_classifier, param_distributions=param_dist, 
                                   n_iter=100, cv=5, scoring=scorer, n_jobs=-1, random_state=4212)

# Fit the random search to the data
random_search.fit(X_train, y_train)

# Print the best hyperparameters
best_params = random_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best model
best_rf_model = random_search.best_estimator_

# Evaluate the model on the test set using F1 score
y_pred = best_rf_model.predict(X_test)
f1 = f1_score(y_test, y_pred, average='weighted')  # Adjust 'average' parameter as needed
print("Test F1 Score:", f1)
# Out:
# C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 165 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 95 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\joblib\parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\joblib\parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
# --------------------------------------------------------------------------------
# 70 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\joblib\parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\joblib\parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 187, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\HP 10th Gen\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.8791642  0.84731264 0.73980263        nan 0.88652171 0.7362636
#  0.90184579 0.87748522        nan        nan        nan 0.84336338
#         nan 0.84207656 0.87631461        nan 0.80109559        nan
#         nan 0.89006858 0.87252973 0.88185511 0.87992399 0.78798308
#  0.84518552        nan        nan 0.88631551        nan 0.8739918
#  0.77408712 0.84037653 0.87978081        nan 0.83977071        nan
#  0.76745648 0.86766856        nan 0.87115663 0.78865948 0.77934372
#  0.85479072 0.822947   0.88966864        nan 0.89313898 0.87791388
#         nan        nan 0.79100098 0.85971041 0.74867212 0.87088743
#  0.87375414        nan 0.89365694 0.82012578 0.87805544 0.88076535
#  0.83678207 0.76427659 0.89393819 0.83964874        nan        nan
#  0.78660801 0.87968239 0.79404485 0.73595842 0.8767192         nan
#  0.87400106 0.74724377 0.88322281        nan 0.83493846        nan
#  0.83847372        nan        nan 0.89497928 0.88248158        nan
#  0.8839019  0.89305956        nan        nan        nan 0.84319428
#  0.88405317 0.88310221        nan 0.79737552 0.87911467        nan
#         nan 0.8918906         nan 0.80758287]
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 150, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 30, 'criterion': 'entropy', 'bootstrap': False}
# Test F1 Score: 0.8685675883256527

# %%
print("Model performance after hyperparameters tuning")
# Make predictions on the training set
y_train_pred = best_rf_model.predict(X_train)

# Evaluate the model using classification report
print("Classification report on the training set")
print(classification_report(y_train, y_train_pred))

# Make predictions on the testing set
y_test_pred = best_rf_model.predict(X_test)

# Evaluate the model using classification report
print("Classification report on the testing set")
print(classification_report(y_test, y_test_pred))
# Out:
# Model performance after hyperparameters tuning
# Classification report on the training set
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       356
#          2.0       1.00      1.00      1.00       872
#          7.0       1.00      1.00      1.00         2
#          9.0       1.00      1.00      1.00         6
#
#     accuracy                           1.00      1236
#    macro avg       1.00      1.00      1.00      1236
# weighted avg       1.00      1.00      1.00      1236
#
# Classification report on the testing set
#               precision    recall  f1-score   support
#
#          1.0       0.81      0.72      0.76        89
#          2.0       0.89      0.93      0.91       219
#          9.0       1.00      1.00      1.00         2
#
#     accuracy                           0.87       310
#    macro avg       0.90      0.88      0.89       310
# weighted avg       0.87      0.87      0.87       310
