# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import classification_report
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
cancer_adult22 = pd.read_csv('cancer_adult22.csv')

# %%
cancer_adult22.sample(10)
# Out:
#        URBRRL  RATCAT_A  INCTCFLG_A  IMPINCFLG_A  SHOTTYPE1_A  CEVOTELC_A  \
# 22875       3        14           0            0          2.0         1.0
# 17492       4         8           0            1          NaN         2.0
# 12714       1         5           0            0          NaN         NaN
# 10872       1         6           0            0          NaN         NaN
# 14800       3        14           0            0          NaN         1.0
# 9295        1         8           0            2          NaN         NaN
# 24918       1        14           1            0          1.0         1.0
# 3764        2         2           0            0          NaN         NaN
# 2942        3        13           0            0          NaN         NaN
# 23405       1        10           0            1          1.0         1.0
#
#        CEMMETNG_A  CEVOLUN2_A  CEVOLUN1_A  HITTEST_A  ...  PROXYREL_A  \
# 22875         1.0         NaN         1.0        1.0  ...         NaN
# ...

# %%
cancer_adult22 = cancer_adult22[cancer_adult22.PROSTCAN_A.notna()]
cancer_adult22.shape
# Out:
# (1449, 637)

# %%
missing_pct = cancer_adult22.isna().mean()
low_missingness_columns = missing_pct[missing_pct == 0].index
cancer_reduced_missing = cancer_adult22[low_missingness_columns]
cancer_reduced_missing.shape
# Out:
# (1449, 268)

# %%
cancer_reduced_missing.sample(5)
# Out:
#        URBRRL  RATCAT_A  INCTCFLG_A  IMPINCFLG_A  PPSU  PSTRAT  HISPALLP_A  \
# 18640       1        10           0            0    18     113           1
# 14610       4        14           0            0     2     112           2
# 15690       4        14           0            2    56     149           2
# 20559       3        14           0            0    91     108           2
# 5589        1         3           0            0    28     137           2
#
#        RACEALLP_A  DISAB3_A  PHQCAT_A  ...  LSATIS4_A  PHSTAT_A  AVAIL_A  \
# 18640           1         2         1  ...          2         3        1
# 14610           1         2         2  ...          2         3        1
# 15690           1         2         1  ...          2         3        1
# 20559           1         2         1  ...          1         3        1
# 5589            1         2         1  ...          1         5        1
#
# ...

# %%
selector = VarianceThreshold()
selector.fit(features)

variances = pd.DataFrame({"features": features.columns, "variance":selector.variances_})
variances.sort_values(by=["variance"])
# Out:
#          features      variance
# 249       CANEV_A      0.000000
# 263      IMPNUM_A      0.000000
# 87        SRVY_YR      0.000000
# 262       RECTYPE      0.000000
# 260      HHSTAT_A      0.000000
# 88          SEX_A      0.000000
# 52    MLTFAMFLG_A      0.008213
# 238       EPIEV_A      0.017621
# 84         HISP_A      0.040957
# 2      INCTCFLG_A      0.042218
# 45         CHIP_A      0.046836
# 223       HICOV_A      0.054936
# 41       OTHGOV_A      0.057954
# 244     DEMENEV_A      0.064838
# 218    HIKIND05_A      0.068185
# 43          IHS_A      0.070300
# 216    HIKIND07_A      0.070300
# 42       OTHPUB_A      0.077264
# 40       NOTCOV_A      0.080048
# 213    HIKIND10_A      0.081434
# 214    HIKIND09_A      0.082808
# 215    HIKIND08_A      0.089624
# 241       CFSEV_A      0.094250
# 250        ASEV_A      0.101437
# 243       ANXEV_A      0.113931
# 219    HIKIND04_A      0.118481
# 246      COPDEV_A      0.122573
# 83      HISDETP_A      0.123902
# ...

# %%
cancer_reduced_missing.sample(5)
# Out:
#        URBRRL  RATCAT_A  INCTCFLG_A  IMPINCFLG_A  PPSU  PSTRAT  HISPALLP_A  \
# 23860       4        13           0            2     1     146           2
# 1031        1         8           0            0    25     117           2
# 10935       2         1           0            0    22     130           2
# 23646       2        14           0            0    10     136           2
# 1607        4        10           0            0    29     149           5
#
#        RACEALLP_A  DISAB3_A  PHQCAT_A  CITZNSTP_A  LEGMSTAT_A  MARSTAT_A  \
# 23860           1         2         1           1           3          1
# 1031            1         2         1           1           3          1
# 10935           1         2         1           1           2          5
# 23646           1         2         1           1           2          8
# 1607            4         2         2           1           3          1
#
#        GADCAT_A  PCNTADTWFP_A  PCNTADTWKP_A  FDSCAT4_A  FDSCAT3_A  \
# ...

# %%
from sklearn.feature_selection import VarianceThreshold
import pandas as pd

# Assuming `df` is your DataFrame

# Create a VarianceThreshold instance and fit to the DataFrame
selector = VarianceThreshold()
selector.fit(cancer_reduced_missing)

# Get the indices of features with zero variance
zero_variance_indices = selector.variances_ == 0

# Print out variables with zero variance
variables_with_zero_variance = cancer_reduced_missing.columns[zero_variance_indices]
print("Variables with zero variance:", variables_with_zero_variance)
# Out:
# Variables with zero variance: Index(['SRVY_YR', 'SEX_A', 'CANEV_A', 'HHSTAT_A', 'RECTYPE', 'IMPNUM_A'], dtype='object')
