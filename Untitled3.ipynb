# %%
import pandas as pd

# %%
df = pd.read_csv('prostate_cancer_data18.csv')

# %%
df.sample(10)
# Out:
#       FPX  FMX    HHX  INTV_QRT  WTIA_SA  WTFA_SA  SEX  HISPAN_I  R_MARITL  \
# 451     1    1  21343         2   9343.6     8368    1        12         1
# 242     1    1  11964         1   4684.4     4122    1        12         4
# 534     1    1  25432         2   9679.4     8668    1        12         4
# 664     1    1  31493         3   3680.2     3262    1        12         7
# 673     1    1  32051         3   8892.0     7880    1        12         1
# 653     1    1  31161         3   7535.7     6678    1        12         1
# 300     1    1  14509         2  14043.3    15287    1        12         1
# 1136    1    1  54470         4  14475.0    13324    1        12         1
# 804     1    1  38666         3   2856.5     2999    1        12         7
# 442     1    1  20901         2   3316.6     4154    1        12         7
#
#       MRACRPI2  ...  DEP_2  PAIN_4  TIRED_1  TIRED_2  TIRED_3  RCS_AFD  \
# ...
